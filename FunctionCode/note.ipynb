# %% [markdown]
# <!-- ### 3 types of envs:
# #### 1. 11*11_empty
# ![11*11_level1.png](/home/siyao/project/rlPractice/MiniGrid/level/11*11_level1.png)
# #### 2. 6*12_empty
# ![6*12_empty.png](attachment:6*12_empty.png)
# #### 3. 21*21_empty
# ![21*21_empty.png](attachment:21*21_empty.png)
# <img src="image_url" alt="21*21_empty.png" width="300" height="200">
# <img src="attachment:21*21_empty.png" alt="Example Image" width="500">
#
#
#  -->

# %% [markdown]
# ## Excel按照目标列名顺序，对数据重新排列

# %%
"""
=IFERROR(
  INDEX($C$11:$AX$15, ROW()-ROW($C$31)+1,
    MATCH(TRUE, INDEX(UPPER(TRIM($C$10:$AX$10))=UPPER(TRIM(C$1)), 0), 0)
  ),
  "列名不存在"
)
"""

# %% [markdown]
# ![图片说明文字](Excel.png)
